# %% [markdown]
# <a href="https://colab.research.google.com/github/OSPK/cyril/blob/master/Interactive_textgenrnn_Demo_w_GPU-cyril2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Interactive textgenrnn Demo w/ GPU
#
# by [Max Woolf](http://minimaxir.com)
#
# *Last updated: December 2nd, 2018*
#
# Generate text using a pretrained neural network with a few lines of code, or easily train your own text-generating neural network of any size and complexity, **for free on a GPU using Collaboratory!**
#
# For more about textgenrnn, you can visit [this GitHub repository](https://github.com/minimaxir/textgenrnn).
#
#
# To get started:
#
# 1. Copy this notebook to your Google Drive to keep it and save your changes.
# 2. Make sure you're running the notebook in Google Chrome.
# 3. Run the cells below:

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Set the textgenrnn model configuration here: the default parameters here give good results for most workflows. (see the [demo notebook](https://github.com/minimaxir/textgenrnn/blob/master/docs/textgenrnn-demo.ipynb) for more information about these parameters)
#
# If you are using an input file where documents are line-delimited, make sure to set `line_delimited` to `True`.

# %%
model_cfg = {
    'word_level': True,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 4,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': True,   # consider text both forwards and backward, can give a training boost
    'max_length': 8,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 10000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 25,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 1,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %% [markdown]
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any text file** and update the file name in the cell below, then run the cell.

# %%
file_name = "text-new.txt"
model_name = 'new_cyril'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# Training new model w/ 4-layer, 128-cell Bidirectional LSTMs
# Training on 497,125 word sequences.
# Epoch 1/25
# 485/485 [==============================] - 82s 168ms/step - loss: 5.2509
# Epoch 2/25
# 485/485 [==============================] - 78s 161ms/step - loss: 4.4048
# Epoch 3/25
# 485/485 [==============================] - 77s 159ms/step - loss: 3.9809
# Epoch 4/25
# 485/485 [==============================] - 78s 160ms/step - loss: 3.5808
# Epoch 5/25
# 485/485 [==============================] - 77s 159ms/step - loss: 3.1906
# ####################
# Temperature: 0.2
# ####################
# be at least clearly in the loop .
#
#  but the n - league has figured out that the army has been hawking lately : the system wrapped up to the logical offer of the process , the boys are willing to shut down the system .
#
#  but the n - league has figured out that the pti ’ s electoral fortunes in kp .
#
#  but it ’ s not just about the politics of the next phase .
#
#  but the n - league has been freed from the distraction of the political and political process .
#
#  the problem is that the n - league has been freed of awkward , potentially , ” said , adding , “ the taliban said , ‘ north waziristan is the global hub of violence .
#
#  the bigger and the state may have been a little more complicated — but it was a price worth paying .
#
#  so let ’ s try and unpack this .
#
#  but the dilemma for the pml - n could win .
#
#  but the pml - n is trapped in a clutch of punjab - assembly seats , but it ’ s not a choice : the army has been able to preside at its own version of the kayani moment .
#
#  the same goes for the pti ’ s core agenda .
#
#  but the n - league has figured out that the pti ’ s goal is to the pml - n .
#
#  but the n - league has figured out that the pti ’ s goal is to the pml - n .
#
#  but the n - league has figured out
#
# be at least rs100 ; and the veneer of state restructuring that is the most of imported jets .
#
#  it ’ s not just the pml - n . the pti is worried about the pti ’ s core interests .
#
#  the problem is that the sharifs are both .
#
#  the army is a bunch of and uncertainty .
#
#  but the pml - n has figured out that neither grace nor are often very hard to find .
#
#  the problem is that the n - league has been freed of awkward , potentially wrong .
#
#  the army has figured out that the army has been able to turn up at the cost of the pile ?
#
#  it ’ s not a good place to be done .
#
#  but the dilemma for the pml - n ’ s core agenda .
#
#  but the n - league has figured out that the pti ’ s strategy has been sucked out of the country .
#
#  so , what ?
#
#  it ’ s not just that the haqqanis aren ’ t going to insist the pakistani narrative of their custody , that ’ s the kind of stuff that mattered , but the pml - n has figured out that the ppp ’ s goal is about as a serious contender and a candidate for a provincial assembly seat , admitted the party vote in punjab is a party of coalition , including rabbani , a pml - n leader , the party has already disengaged .
#
#  the problem is that the sharifs are both .
#
#  the pml - n is a decision to speak on the party
#
# have to consider the army to the top slot in the name of the last chap , the pml - n has been artificially pegged back .
#
#  the n - league has to be freed of the party ’ s winning strategy .
#
#  but the n - league has figured out that the pti ’ s strategy has been sucked out of the prism of the nuclear programme .
#
#  the army is a bunch of and uncertainty .
#
#  the army has figured out how to be the enemy to do .
#
#  the problem is that the pml - n is trapped in the southern districts of the army ’ s population , “ it ’ s not a matter of time .
#
#  but it ’ s not a bunch of stuff .
#
#  but the pti ’ s strategy in the party faithful .
#
#  “ the pti ’ s strategy is not always to find .
#
#  the other option is the same .
#
#  the problem is that the pti ’ s goal is to the pml - n .
#
#  but there ’ s a simpler explanation for at the private sector .
#
#  the problem is that the sharifs are silent , they ’ re all powerful and they ’ re willing to do what they want .
#
#  the unthinking fracturing of state and society is a dangerous mess .
#
#  but the pml - n is a decision to match .
#
#  the court has chosen the army ’ s intentions .
#
#  the problem is that the n - league has been freed of awkward , potentially wrong .
#
#
#
# ####################
# Temperature: 0.5
# ####################
# , - a - minute - the - enemy , the boys want to improve , not letting others think about it .
#
#  but the dilemma for nawaz has been that he ’ s not ready to take over .
#
#  now , it ’ s not a good place for the terrorist .
#
#  the court itself was that the process of chaudhry had revealed in the air : judge c is a favourite from quetta , rendering the current stage could be the result .
#
#  + - +
#
#  the paradox of a campaign
#
#  “ the state is a victim of a policy .
#
#  but the problem is that easy enough to explain .
#
#  so why not delay the boys ?
#
#  so let ’ s try something else , but the alternative ?
#
#  well , if you ’ re a civilian , you ’ re thinking .
#
#  and that ’ s the problem : the core interests have become a tool of the pti ’ s core interests .
#
#  but the n - league has a way to do with the pti .
#
#  but it ’ s not really the other side .
#
#  but the forced variety that the state itself has yet .
#
#  it ’ s just that the unpleasant question is imminent .
#
#  the other option is the same : the mqm has dangled a phrase a foreign - policy agenda .
#
#  but that ’ s where the unpleasant question is deemed acceptable .
#
#  it ’ s not like referendums aren ’ t any convincing .
#
#  the era of the spy
#
# of the state and the state .
#
#  the court has been pressed at the loop .
#
#  but if you ’ re a civilian government or not .
#
#  the logic of a state that is supposed to become the job , the more he will be more interested in the interest of the state .
#
#  and because of those meetings can ’ t be ignored .
#
#  but the forced variety that the state wants to be dealt with the americans .
#
#  the other option is a little more skilfully ; the state apparatus can be dealt with the americans .
#
#  so , if you ’ re the civilian wants to keep the other cohort , how to make the boys complete their term ?
#
#  the 18th was never about verifying , educated and thereby have some access to the taliban . ”
#
#  and while the army is at stake , ” said , adding , “ we will be a candidate for a pml - n ticket .
#
#  he ’ ll likely find the way to the supreme court , but it ’ s not been clear if you ’ re a civilian government or a politician who has to do it .
#
#  it ’ s not a bunch of stuff .
#
#  or , really .
#
#  that ’ s the problem .
#
#  but the sharifs are at all the time .
#
#  so , let ’ s try and unpack this — you ’ re thinking , you ’ re thinking . the knockout blows were fired , but the pti was on autopilot and the pml - n made up under
#
# military control of the 18th .
#
#  by itself , there ’ s a crisis to be repeated .
#
#  the army has figured out how to be the ‘ equal ’ and ‘ moral ’ , non - muslim and strong candidates .
#
#  “ i ’ m not expecting a tough fight in the constitution , i have been released and we ’ ll find a good place to make the civilians dabble around the key .
#
#  for the ppp , the sindhi is the party .
#
#  but it ’ s not really the great deal , but the system is broken .
#
#  the nsg exists because of a bunch of road and , the state ’ s finances and contributions to the vast majority of the ihc .
#
#  and now , the pti ’ s core interests have been turbocharged . the n - league has been artificially pegged back .
#
#  the n - league has figured out that the pti ’ s strategy is paralysed , but it ’ s not a force , but never really quite obviously just one way to the trigger .
#
#  it ’ s not just the nature of the boys .
#
#  they ’ ve seen the big ones we ’ re built on two sides : the pml - n leadership and the pti ’ s support for punjab .
#
#  but the pti has also only weeks into a vast majority .
#
#  and now that the jokers and clowns has made it possible for a minute . it was violent . ”
#
#  privately , officials claims , “ there ’ s no reason the pml - n
#
# ####################
# Temperature: 1.0
# ####################
# most of the university if you think about it , it all be .
#
#  a military court hearings continue to speaking to some other questions .
#
#  but then there ’ s not how it is done .
#
#  it is more than those who suppressed , would have been bowed for a fourth time . i could be aware , who was set to end about 2 . the boys have parts it is fundamentally interior — is fairly individual ; the country functions , cap in guantanamo bay and sugar community that is also possible to nomination papers . but when the political career imminent — debate will become a country — pretending nobody is so lucky . especially when men had come to a tree of all the trouble and .
#
#  because most of the silliness about imran ’ s 35 years , was never going to mean violence inside pakistan instead of a manipulated government and its real estate ; weakness of kashmir — on afghanistan .
#
#  so do the approach to ever again .
#
#  try this government , y ’ know this is manage things , ” said : “ everyone knows who has done nothing . for all the bodies , but there are two cards to produce results .
#
#  from gen k , the punjabi who talks weren ’ t willing to contribute itself — their counter will argue against longer .
#
#  an infrastructure for state - fuelled paranoid here . i spent on the doors , lahore and the losers could be shaped by the reasons for problems to suggest the election itself , but the voter is at vote more than the people to accept that america
#
# on a party or needs to do early on counter .
#
#  so - called prisoner releases , and - beating up notice of the old community by human media groups to have meant that the myth we were actively neutralised .
#
#  who loved pakistan . a freewheeler unless we get what khwaja asif khosa and he up . but indicate mode of love talks anytime soon to mean anything about nawaz .
#
#  the n - league may or aren ’ t possible for him or the party with no ouster .
#
#  + - +
#
#  well - meaning new
#
#  but suddenly nawaz did not pass . in the already game , there ’ s little more suspicion .
#
#  theory , but it ’ s not just been for the ceasefire . at the centre , it seems to be marginal ; and even without space in the supreme court .
#
#  make a rather deal ?
#
#  mushahidullah has decided the army is relatively porous ; the chinese are pretty dead and the constitution , no responsibility to nwa , some other party matter little is : closer to asif .
#
#  he is a good administrator . a fresh miscalculation on democracy , imran swung to other kinds of those events — and all the hard work is built on to the next election , because it ’ s not as a bit open to .
#
#  regular president , geo ’ s had to make kids outmanoeuvring the hour in the pm , but the way of an court ’ s approach has emerged or will it set on engagement next year after two hole .
#
#  for nawaz .
#
# and adjoining areas here are as a red .
#
#  because , well , to build the crisis and will it changing the legal kind of its own political will use is a problem for 2020 . ”
#
#  privately , the closest allies , nothing better .
#
#  the excitement is dismaying .
#
#  but on that figured out there ’ s been the first few stations in a thoroughly avoidable accident to talk , never heard of the stuff we ’ re built on nawaz ’ s wagon to jail and damaging a mess that funny business has been taken over .
#
#  the chaps claiming responsibility haven ’ t hid both defending and attacks from quetta . ”
#
#  it ’ s fake true . imran is unable to influenced by the boys pretending you ’ re not . everyone can drive away with the court of his leader , speaking to his head : cautious , 000 to engage in the constitution of balochistan and make it clear ? maybe not him again and in the room or to fix the country , just don ’ t really know what they want .
#
#  it ’ s personal as hard - business rank and figure out early into the region , which is selling the electoral reality .
#
#  minimum deterrence scoff at the right issue if nawaz stays new politics .
#
#  it ’ s all that time by intervention .
#
#  if there ’ re only one sophisticated one drawn at the collective of other side , intervention may have made it complete — imran is doing what he wants to do is .
#
#  the obsessive focus on the nfc and military
#
# Epoch 6/25
# 485/485 [==============================] - 78s 160ms/step - loss: 2.8264
# Epoch 7/25
# 485/485 [==============================] - 77s 159ms/step - loss: 2.4989
# Epoch 8/25
# 485/485 [==============================] - 78s 161ms/step - loss: 2.2145
# Epoch 9/25
# 485/485 [==============================] - 78s 160ms/step - loss: 1.9684
# Epoch 10/25
# 485/485 [==============================] - 77s 159ms/step - loss: 1.7539
# ####################
# Temperature: 0.2
# ####################
# . or so , what ’ s the point to engaging with these people at the constituency level .
#
#  “ the situation has been slick , ” said , a senior pml - n leader , explained the districts of the ppp and donald trump , explained the gda , of course on the election .
#
#  the problem with khan is that he ’ s just recently disappeared from na - 42 , where the biggest problem was evident in the court :
#
#  the first chief , nawaz , from the pml - n .
#
#  the pti ’ s rivals have been a failure of itself and the hard of power .
#
#  so let ’ s start with the illegitimate reason .
#
#  the first is to replicate the current political landscape .
#
#  but the friday ruse worked in a long , decades on the same , more often than the other side .
#
#  the only thing that changed between the 2015 senate election and and in recent times , the n - league has a theory .
#
#  so , that ’ s the problem .
#
#  the problem with khan is that he ’ s interested in the same position , but the provinces are to be within ; and there ’ s a lot of them in the next parliament .
#
#  there ’ s more . the clock is winding down to the taliban and in the east .
#
#  the ttp came from here .
#
#  the battlefield is a chief and a dgi tainted as one by the many in opposition .
#
#  the other part of the dharna , is that rallying
#
# the cycle of terror attacks , the us war ; and pakistan ’ s growth for pakistan ’ s nuclear programme and the possibility that the state is failing to reject the other provinces .
#
#  the more you stress normalisation in an environment where no one else wants it , or at least one of those things to help the boys ’ attack on the side of the border .
#
#  the infrastructure of jihad ? the mosque - madressah - social welfare network , has argued that the finance ministry of the ttp dialogue had begun to be and that it ’ s hard to have a choice .
#
#  the pml - n is not trying to limp on and the like .
#
#  so , to put it bluntly , the kind of people would be to pressure from the of the worst .
#
#  the pml - n is not trying to limp on and the like .
#
#  the tweet was more than the third tier of the boys ’ legal side , the government has managed to be a version of its own .
#
#  the end is an old , legitimate - sounding - like - they - had .
#
#  the first one is all that matters is the first chaps in : the race ahead of the taliban .
#
#  there ’ s a contradiction at this time round .
#
#  the problem is that the end may be .
#
#  the pml - n is not trying to limp on and the like .
#
#  so , what ’ s the point to engaging with these people at the constituency level .
#
#  the ppp has
#
# to them . they ’ re sure they ’ ve got themselves in : they ’ re hard to find a new chief .
#
#  the old nawaz , the anti - democrats , the boys ’ t — the boys ’ mess .
#
#  there ’ s the stupid way . but the problem is that the end may be a little bit of it .
#
#  the problem is that the of the army is seen to keep the pressure on pakistan ’ s way to the end of the big little thing — and it ’ s really the same thing that he ’ s shown is that he ’ s taken over .
#
#  it ’ s the second part of the story though : the chief - cum - chief himself was to clean up the dharna , but the ppp has failed in particular , is now effectively a new phase .
#
#  it ’ s not a good start for the boys .
#
#  + - +
#
#  the four who would rule
#
#  the most likely outcome is to have been in the interest of the taliban .
#
#  the international establishment , led by the us , ‘ what ’ s our world , we ’ ll have to find out the biggest and rough money they can get on with is the core part of it .
#
#  so let ’ s talk about the boys ’ preferences .
#
#  the boys , according to this dark theory , of the pml - n .
#
#  the pml - n — the ppp and pml - q .
#
#  the ppp lost ground , kp and balochistan
#
# ####################
# Temperature: 0.5
# ####################
# hope they get us .
#
#  the pay - off is to the point that they ’ re being sure how to do anything about the sanctuaries on the ground .
#
#  and the investigatory lot will help with them to themselves to the mat , they ’ ll have to learn how to fix things .
#
#  and the investigatory lot will have a nice ring to go on 3g : the few of us , decisions are not to us .
#
#  the conversation about what to do with pakistan is that it isn ’ t a sectarian conflict . a big , military operation in the state and society — and the government is acceptable to them — that ’ s the core of all the things that have changed . they don ’ t have the expertise and the system that he had to play out , he will .
#
#  so , for all the speculation about the pols who could have wanted to be heard of pity here . ”
#
#  from jan , pti candidate , pml - q have been an of and more focused on the civilian side , the voter and the other — more judges himself in the same imagine he was going to be with musharraf .
#
#  and then there ’ s the other theory that nawaz has made his political agenda : he ’ s shown the big decisions — or the rest of us will bite , it ’ s a bunch of politics of the country .
#
#  but what ’ s the point to engaging with an issue on the american side : the first with the ttp .
#
#  the nasty thing about
#
# . but what ’ s the point in doing whatever ’ s necessary .
#
#  the other is also too clever to the enemy ’ s ranks .
#
#  so let ’ s scratch around a bit .
#
#  if pakistan wants to send troops , they ’ ll be forced into their own , and there ’ s nothing — nothing — nothing — nothing — nothing — that ’ s the crisis .
#
#  the court has long argued that it ’ s hard to feel the pti that ’ s been another thing at the end of the year , the americans have been more happy . so , what ’ s the point to engaging with all voters that he will succeed in the party , ” claimed riaz ahmed , a local journalist .
#
#  “ after the by - election , it looked like tariq anees would be very hard to beat , but the situation has changed since then , ” inayat added , referring to a december by - election for a provincial assembly seat in which anees ’ s candidate thumped both the pml - n contender and a candidate backed by aziz .
#
#  anwar aziz , danyal ’ s father who looks after constituency politics in the absence of his son , was also cautious : “ tariq anees will be very tough to beat . but the pml - n ’ s version of its agenda , but that ’ s the macro picture .
#
#  but the so good is imran that the taliban have got under the skin of the us : it ’ s our boys ’ .
#
#  but the pti seek to its own version
#
# four , civ - mil . it ’ s a political class that can ’ t be managed to be the rule of our crisis .
#
#  but if it ’ s all been scrambled and predictable and stale and unstable .
#
#  because it ’ s a beautiful , ugly thing .
#
#  the only answer comes down : the other side of the state .
#
#  the only thing that changed between the 2015 senate election and the 2018 senate election is that the n - league is more interested in cpec politically than ever .
#
#  but the opposite of the nawaz team is that he is ready to be within .
#
#  and then there ’ s the other side that everyone knows the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , the boys , and the civilians , well , and they ’ ll show them all into a trial and maybe even then they ’ re hard to find a one - off between the in the middle of nawaz ’ s .
#
#  the pml - n is not trying to limp to the other side of the table .
#
#  the problem with the question is that nawaz ’ s electoral self - immolation has changed his mind .
#
#  imran may have learned the great deal with the americans want to go after the bad stuff — the one he tried to watch the system himself and didn ’ t know what he
#
# ####################
# Temperature: 1.0
# ####################
# the politicians as the public .
#
#  to block the changing nature of days and flowing particularly in on the day of the day he had karachi even now is focused on several things that .
#
#  anything longer , the outside powers is precisely the next nawaz .
#
#  worried about imran ’ s war . chaudhry was in with a particularly 11 version . if nawaz fails in washington , he had proved wrong since his decade .
#
#  assume power at the centre and the last . but it ’ s also a vital resource : the ppp has an public at its near from punjab ’ s good cause . that ’ s mumtaz qadri . or it ’ s more about to be something else : do better or not . but what does that mean should be ?
#
#  the anti - democrats will want , we need that job with us , but to get to cut down to the broader lot of politics , for electables and until the santa ’ s enemies tried to be returned to the competent authority in the ’ s nose party leaders with a push on : pml - q ’ s prospects in a province in depalpur ’ s constituencies , but unlikely on the economy .
#
#  + - +
#
#  on a mobile phone ? get the dawn mobile app : apple store | google play
#
#  ever , the ppp , the mqm and sindh , mqm — and possibly as a reason .
#
#  pick up a success , that the politicians will eventually show reluctance to overcome thinking , ” the senior - most chief ) said that once again favours
#
# , happy birthday to a bunch of people .
#
#  you can ’ t say that people fear aligned with winning asif and contribution - lined after the punjab assembly months in this year .
#
#  busy nawaz ’ s election they ’ ve claimed that the game has set against musharraf to cede what he was : until you another . be afraid to do the thing — until there is a good thing .
#
#  it ’ s our job , there ’ s a fourth problem to find . well , he ’ s yet . as if he had musharraf , he tried it wrong and no one has had enough .
#
#  before the panama hearings and the 18th matter . gen k has tried a bit .
#
#  this time , that ’ s a lot of it ’ s apparent to running 2013 . if he still has to the provinces , it won ’ t work .
#
#  then , can india and kill off a place . for that we can get them – and they talked their right - wing . after the pm ’ s more political machine .
#
#  politics was the faizabad . an operation in the supreme court would be taken by is clearly .
#
#  that formidable machine is pressed up , the of shah — reputation has been heard before pakistan in peshawar , the has to figure out the whole truth about what is the new class of missing persons .
#
#  you ’ d rather have to be the guy ’ s guy . you can imagine nawaz going off script for your return .
#
#  women would break from the war
#
# to the provinces achieved that you ’ d take it along .
#
#  and then there ’ s the guy who can ’ t write the civilians from the militancy threat , welcome to the haqqanis , ” a government official said .
#
#  the supreme court option was not a judgement that make sure he didn ’ t have the expertise and he ’ s out - part and a new configuration in the peshawar valley have voted in this area . ”
#
#  the most spoke as mr chotiner , author of a clear who hound immutable : the country or which had made everyone happy to think about a conflict the army may be able to try and break into the political threats ?
#
#  so , do the haqqanis as keep stuff onto the pakistani state , in india , being no one in ever since the ttp would necessarily see .
#
#  so let the political fortunes turn against you to be selected and ”
#
#
#
#  the pml - n ’ s mistakes began to the district , in begun set , the road and real .
#
#  usually , boys ’ fazlur rehman was a diminished party member from a zardari - pml - n leader who is now an open question : is emerging as many iterations — potentially , when way fight at this time crisis , which has created a strategic change that between the two ppp and senate purposes didn ’ t really think a strategy doesn ’ t mean the end itself starts to gain much traction , what did that equal do is fairly obvious : there ’ s even when just by ballot stuffing , turnout will be
#
# Epoch 11/25
# 485/485 [==============================] - 78s 160ms/step - loss: 1.5614
# Epoch 12/25
# 485/485 [==============================] - 80s 164ms/step - loss: 1.3962
# Epoch 13/25
# 485/485 [==============================] - 79s 163ms/step - loss: 1.2440
# Epoch 14/25
# 485/485 [==============================] - 78s 162ms/step - loss: 1.1064
# Epoch 15/25
# 485/485 [==============================] - 79s 164ms/step - loss: 0.9822
# ####################
# Temperature: 0.2
# ####################
# , what can be done and he ’ ll have to be prime minister .
#
#  the pml - n — the pml - n has learned that neither side has a solution to it , the more likely you get what , the other institutions , a whole lot . it ’ s a bloody crisis .
#
#  the problem is obvious : rage expressed against external actors has effects internally , but to be afghanistan .
#
#  the boys , according and interesting are on the other side of the .
#
#  but the thing was , it was mishandled by them . but it also works very much for the usual suspects : politicians know the boys and their leaders .
#
#  and the stories are .
#
#  if you ’ re nawaz , you ’ re thinking . it ’ s not the ttp .
#
#  the court has long to establish itself , à la bush , as the decider . if there ’ s a dispute on hand and a bit of them to the and we ’ ve got it right .
#
#  + - +
#
#  on a mobile phone ? get the dawn mobile app : apple store | google play
#
#  a tale of many way to the court ’ s advantage .
#
#  the pml - n will survive lahore and tuq won ’ t bring down the government . but that doesn ’ t mean it ’ ll happen .
#
#  the boys are busy counter - , but sindh , its own , his spiritual version of the new job , where national consensus the boys down is the same .
#
#  + -
#
# , what can be done and we ’ ll get it .
#
#  it ’ s not that nawaz has done anything fundamentally wrong on the governance front ; it ’ s that he ’ s done few things right , he ’ ll have and still doing nothing .
#
#  the answer , though , is better than the boys ’ internal predominance .
#
#  but that ’ s the way the taliban ’ s peace process ?
#
#  the problem is , that configuration the prosperity goal .
#
#  the boys have their reasons to their boss is to do both . but then he ’ s been going .
#
#  but there ’ s a militancy problem but he ’ s learned , he ’ ll have and been more of a problem .
#
#  the pml - n and the pti are stuck in the election , the ppp ’ s base in the cities , but the game still stuck in the election — when the old order is about security and the like .
#
#  the khaqan threat of the ppp and the military .
#
#  but the supreme court option was a bit of .
#
#  but when the old centre was at the time , the general election should be held on time .
#
#  but the old centre to pakistan — the army high command has given its full hand - on - of - the - same is the old nawaz : in the world of imran , in the he of all the vision , the end were somehow .
#
#  the other alternative is a lot of help us , the politicians themselves are looking for
#
# , what can be done and he should make an open - up and two - thirds of the way in which .
#
#  the pml - n — the pml - n has missed a big chance .
#
#  but the n - league has resisted the idea — the groups weren ’ t created for the party .
#
#  the ppp didn ’ t need to win , the boys have the will . but it will only be obvious , but the final impasse is the same .
#
#  the boys , according to this dark theory , know the state has two more so it can be .
#
#  the problem is that the persistence of no - name winners likely will end up doing the opposite of what it suggests — though , is that he ’ s grown , the first makes them worse than just unity and even the most bloated of power — the boys have stuck in the same . where the ideas are out of the middle east , so why not give them time to fall ?
#
#  the next time of ppp in government is a better of a willing imran , the boys would have to take over .
#
#  the first trick was to neutralise the successor , the current cjp .
#
#  the real problem is that india is bad for the state of pakistan .
#
#  the only thing you can see why that would have been an acceptable price of this new phase .
#
#  the karachi airport attack gave us zarb - i - azb . it was a first meeting , but it was not an outright veto by the boys
#
# ####################
# Temperature: 0.5
# ####################
# , what is the right kind of them ?
#
#  but the ppp is now in a power system can ’ re - too good around for a second believe that something could be a new rule , but the voter isn ’ t all that mattered , but the original sectarian divide in phase three morphed into a fierce militancy on one side of the majority sect that needs to benefit the country .
#
#  the end of the assemblies has also helped partially answer two other questions .
#
#  what is nawaz ’ s sin at that something .
#
#  it ’ s a story that ’ s been buried in the regionalisation and fracturing of the electorate over the past decade or two ; and the rest of the pml - n will fail .
#
#  the pml - n is not trying to bribe pti mnas into staying in parliament . but the pml - n seems to believe that the rural influence will dominate . it ’ s a funny mood out there .
#
#  in the murky world of jihad is familiar , in story , we ’ re stuck trying to undo in six or eight weeks or the ppp ’ seat count from kp to sindh to hold in balochistan and ppp in punjab .
#
#  but it ’ s a new world out there .
#
#  you don ’ t want the pti to do it — or even , ever — nothing .
#
#  it ’ s not that nawaz has to go with him . but the system is clear in the direction of the other government .
#
#  the boys love their games , but the sharifs are
#
# , though perhaps it ’ s just a sign of it .
#
#  but it ’ s not that nawaz has been in the wrong strategy at the heart of the state , nawaz is in retreat .
#
#  the answer to him is to those who — and soon , it ’ s the of your first makes it a more difficult if you ’ re this ; and this is pakistan .
#
#  it matters less if a musharraf trial could have given him that nawaz wasn ’ t able to control the national agenda as a post - 2014 arrangement .
#
#  the chief ’ s tweet was obvious enough .
#
#  there were two problems apparent in the quest to oust nawaz from politics to the second addition : imran , a losing prime minister , there is a new party and a of core agenda — can become for the pti to once a parliamentary party wins .
#
#  you can ’ t see a or two - star sidekick on a record or two - year budget : nothing more than the court the political will have been given a new government that were called . bb
#
#  it ’ s been a good week .
#
#  but that ’ s where the other three factors kick in the final few other choice : don ’ t get to pick up the afghan government or the other half jettisoned , the pti ’ s political opponents was their electoral exercise .
#
#  in the tawdriness and and whining that politics here has been reduced to and reduced itself to become clear because no one had a few of , or no one .
#
#
#
# as they have turned around , more in a modi way .
#
#  the last time , it ’ s been one of the more transparent politicians : he was talking about it and not publicly , or at least .
#
#  the problem is obvious : rage expressed against external actors has effects internally , but because they ’ ve already know who owns the 17 : getting the eye on the india - pak foreign policy stuff , ” the official said .
#
#  you can ’ t really see the other way : the ouster of the pm and the last five years ; the jui - f — pti doesn ’ t need to be an operation .
#
#  the good news : the boys don ’ t know what .
#
#  and , in this counter - insurgency ?
#
#  it ’ s not that nawaz has cultivated since helped .
#
#  but as the pml - n did the right thing and nawaz may be setting the party , but the pti is the election it ’ s probably that the n - league is more complicated and more likely , the more doing so , the boys have decided to do their job or the civilians have or the long government , so many of that ?
#
#  the question is , a bunch of office but a country really more than fact — how much will happen to pakistan to the centre right and the messy , for the sake of never mind .
#
#  and why should he do away with what he won ’ t get away with it , but it ’ s not like we were going to get
#
# ####################
# Temperature: 1.0
# ####################
#
#
# the north and the west may well , so could become .
#
#  but after all , the self - appointed custodians of the public interest — those of virtue who best — and , well , almost as hell .
#
#  the asif zardari to think the story though set on the threat to put it another way , the boys ’ core interests , together , if you tried the deal with a stop interfering in front southern punjab , the energy has been and the fact of way to central punjab will do something about and only government getting built on .
#
#  kinda like ttp to know exactly what ’ s going wrong : the post - 9 / 11 relationship is truly and a fight here , for fast .
#
#  because of round and continuity there has been another round . aside , there ’ re the afghan taliban . but never was . but for all its projects already , the boys have lost since 2009 again .
#
#  if everyone is a gets , they can ’ t .
#
#  comeuppance , hamid khan out . “ a certain who could the and not really threatened to pull him off one and let his wounds . that the n - league seems to have figured out that he ’ s trying to build pressure .
#
#  which means anti - corruption is any militant groups under the needed .
#
#  it ’ s pretty clear he ’ s having to get the fair money into the senate ? it ’ s time to hope so far . nawaz is one of those weeks and may come election time .
#
#  so
#
# keep the army on the taliban friends and the losing the land long greater than thought of it . and how much had come a ttp , you have a mumbai or a pathankot or a slight ratcheting up or down with a seat being questioned , or still in the dark of the world , that ’ s one big thing : a politician who ’ s been around for this week . heck , when he thought through his mind , is actually in making sense .
#
#  turns out into the isi .
#
#  pak - india has been a little every little bit . sure , as yet another is wrong .
#
#  the mistake the n - league has made it out a new government is beginning to be made .
#
#  all civilians hear their man .
#
#  and bajwa is already seen off . scratch around this time . man against a peace - loving people . every new leader of a trump supporter in the he possibly as a national assembly , and it ’ s walked back in the electoral realm and the pti ’ s electoral system , somehow the fear of the infrastructure of jihad , chaudhry who wasn ’ t interested in politics , it would be an almighty or else of sorts , few will come to , a better khwaja , whack more .
#
#  + - +
#
#  so , so there ’ s an enemy to keep these in the wider .
#
#  in the most of two years ppp in july and the ppp was by the pti , the pml - n had little doubt : it was so little that zardari has been
#
# , to a woman . no , everyone , no , no , no , ’ re all back in taliban .
#
#  imagine a military - works understand the power sector , sometimes a ’ and result . political success .
#
#  team , exactly , is a most issue . if nawaz goes to power , he wasn ’ t won ’ t for a coup . ”
#
#  america insisted that nothing to go for that away . wattage and politics . so much of it matters . as imran and nawaz . it is personal as it always and necessary to the four of this matter : the project that the other chap in the pml - n .
#
#  the pml - n isn ’ t going to convince khan , the veto of what he can do to do want to out of the constitution . the politicians are what they are on about the economy and the americans .
#
#  what about the party said that he could do the mind of last august .
#
#  the second one last year ever became less than the moment even more , more like a high - only national institution .
#
#  so if you ’ re the anti - mullah rhetoric , a real producers came up .
#
#  the moment for the pm who made lahore a few months from sharif , where decisions will help the boys ’ muslim relationship again because he wanted more . he had his first view to the people for pakistan . there is also speculation that may still be airports have an old problem : dismantling the public to governance , by the middle who meaning the party
#
# Epoch 16/25
# 485/485 [==============================] - 79s 162ms/step - loss: 0.8675
# Epoch 17/25
# 485/485 [==============================] - 79s 163ms/step - loss: 0.7685
# Epoch 18/25
# 485/485 [==============================] - 79s 163ms/step - loss: 0.6726
# Epoch 19/25
# 485/485 [==============================] - 78s 162ms/step - loss: 0.5876
# Epoch 20/25
# 485/485 [==============================] - 80s 165ms/step - loss: 0.5164
# ####################
# Temperature: 0.2
# ####################
# course , the of the state and the long of political advantage .
#
#  the imf knows that when the court has yet .
#
#  the pml - n has three options : the boys can ’ t — they can decide what ’ s going on here .
#
#  the world gets more alarmed .
#
#  and it ’ s not like it ’ s being done by the boys in punjab .
#
#  in the rural love it out , but the pti is doing something better .
#
#  the — and the anti - india lot .
#
#  but hang on . you ’ re nawaz . you ’ re sick of all the blows you ’ ve absorbed in recent weeks without even getting in a punch or two of your own . you want to make the point of what ’ s probably good for the ppp .
#
#  the pti may have been pretty much the pml - n ’ s strategy — it ’ s already obvious that matters now : he ’ s got an opinion on his way .
#
#  but what the heck is up with imran ?
#
#  it may or may not get him out now .
#
#  but the big - picture stuff has been overtaken by the here and now . what was the point ?
#
#  the problem is that while the politics of the pti is still seen as a problem in the election larger than a seat and in the two provinces , the ppp has a second chance to get the party in parliament . ”
#
#  and while he ’ s got under his brother in jail .
#
# bigger , roads , elections . all those are only ones in recent years .
#
#  there ’ s nothing really the government can do about the media wars . that may be hard for a fight in punjab .
#
#  an obvious neither judge the state seems to have figured out that it needs to be down .
#
#  the real battle is that the new cross - border terrorism attack in fata .
#
#  if necessary , a national assembly , a that is still chief with a prime minister , the court of chaudhry in the have now .
#
#  the pml - n has three options : the boys can ’ t exactly on its place .
#
#  the best ? and the only stuff is clear : he being part where he ’ s wanted to go home . he ’ s right now , he ’ ll have two full - mullah or two - way fight .
#
#  but that could be an opportunity , but it could have been straightforward .
#
#  the point is not . hyper american policy has been and celebrated on a of — over in the media — in the way , the ecp has set its sights on the pti . a shot at the heart of zardari ’ s term — at least it will be the election government , you can ’ t help but wonder if the right kind of stuff is possible , but with a military leadership to make - in from mumbai ’ s way to go with space for whom . instead , there ’ s an election that the state is — and it will be eventually a little extent
#
# course , the of the state and the long of political advantage .
#
#  the worst case scenario is that the n - league ’ s finance team actually believes the amnesty could net a great deal of money .
#
#  but then , to the extent that the new chief did not on , everyone ’ s will of an outright veto . a general has been for his own — what the hell do you need and do with it anyway ?
#
#  the problem is that there is the pre and the ppp . the ppp has been in power for now or is a shot at something better : until something first .
#
#  the pml - n ? the pti had also been able to get its stride again , turned attention to one another round of their : means the public is needed . and if you don ’ t care about politics , you ’ re humiliated . if you go to a state school or college , you ’ re humiliated .
#
#  if you go to have a passport made , pay a or collect a cheque — you ’ re humiliated . if you go to a state school or college , to have a government at its help can better and say , and before that , could be sharif ’ s long - good luck and success has to be taken over .
#
#  that ’ s the problem with the question of : taliban rule equals a few hand - wringing and my party , not want them to parliament ?
#
#  but nawaz can still roar back , he ’ ll always succeed .
#
#  but that still
#
# ####################
# Temperature: 0.5
# ####################
# course , the most sure doesn ’ t mean that a coup can do .
#
#  + - +
#
#  a new kayani moment ?
#
#  this business of trashing the second to last chief and opposing the last one ’ s saudi sinecure , it ’ s vintage imran — loud , brash and unpredictable .
#
#  assuming the boys wanted him out , the system they had to grow more than a few will be able to get that something on the ground .
#
#  the squeeze of that . the politicians and the ones with each outside and the taliban .
#
#  the theory is , it ’ s hard to see what advantage in the next limited .
#
#  yes , the civilian side could be a bigger factor , but the sharifs ready to grow rich attention — they ’ d have to be in a new generation .
#
#  the problem was that he ’ s been around to get the ttp to the government that fight us and the americans had to get us — we can ’ t tell them what he ’ s thinking , not even able to hit the necessary , he won ’ t even expect pml - n .
#
#  the zardari logic seems more bluster than fact at the moment , but the sharifs may have to be the right - wing electoral system .
#
#  why is the principal demands or committed , and the was and never truly over to chaudhry . the n - league is deeply anxious about the army . mistakes , big ones , are being made . if it ’ s the latter , the political lot will be
#
# .
#
#  the ones with several at the original ppo the former by - election , but was by - election was a significant and now of the ppp , ” according to hasan khan , a of the family will be proved to pull the trigger on ouster .
#
#  but the n - league has a is of a bad run for the thought - a - like swap aren ’ t a .
#
#  the boys are going to get their situation into it ?
#
#  with the n - league base , the pti are with an almighty election .
#
#  but the ppp was desperate , the seraiki vote was its only chance in punjab and an election had been fought .
#
#  “ the chief justice will the of the present .
#
#  but for all the talk of afghan - led and afghan - owned and intra - afghan peace and the like , the problem is that pakistan ’ s strategy has been to be less than many , pakistan is , in a new dispensation or a bigger .
#
#  but it ’ s possible that for everyone else to keep an imran on his greatest rival to make electoral legitimacy .
#
#  the end of the same era though is a one thing , one that one , second to go , the chief had already been lost .
#
#  on india ’ s to you . it was a man who could have thought , hit something or get on because it ’ s all very wrong in the ppp ’ s seat count for survival .
#
#  but the security state seems to have to make war
#
# is the most likely step towards the pml - n in punjab .
#
#  the first is easier to explain . granted 90 - day detention by a change of the law in a conviction .
#
#  but there is a problem : the closer the election draws , the less time to a thousand and haven ’ t the caretaker government getting along with the idea of politics .
#
#  that is partly the reason why farzana is dead .
#
#  the second story is of the contest that the party has an electoral electoral scenario .
#
#  the nawaz camp is usually pm , not your job , but look , maybe it ’ s not even in waiting for the right thing .
#
#  the choice — and many desperate to take it , other players , to begin .
#
#  what , for example , are the risks of waiting until nov , when a new chief could mean , the court had already won ’ t get through the fight in this democracy fight .
#
#  meanwhile , what about ?
#
#  either the us can ’ t know , but the only thing we don ’ t know , but the party can ’ t stop the . the pml - n will focus on modest but obvious delivery .
#
#  first — nawaz was supposed to be the leader of the army .
#
#  and , inside the us and china .
#
#  but , yes , , yes , the mqm had made no attempt to wait for civilian officials in the standing committee , of the established that the military , real power — the two hundred million to
#
# ####################
# Temperature: 1.0
# ####################
# the ttp would of war down the narrative that is india and we ’ ll have to deal off . we need more information .
#
#  an economic crisis on pakistan that we went on to the indian side of resources general at general .
#
#  but , as ever , lead in the hands of some and the other .
#
#  here ’ s what difference between all that ?
#
#  nawaz seems to see the zardari way — if not what they think ?
#
#  comprehensive and mullah omar ’ in pakistan ’ s role as much , nawaz and co may decide what he ’ s doing — but he ’ s getting his right side ; a broken system was in a situation .
#
#  back in the day , back in a year or two , change or not , we over .
#
#  game , the boys will tell us exactly how he ’ s doing . everyone doesn ’ t want to talk about . and the civilian does fix it .
#
#  years now . we ’ re all a good bit in , for all of us . he wants to talk about x ; the boys we all know what the chap in afghanistan did with us in the good place on the national stage and it ’ s an to - though it .
#
#  including crony capitalism , and very much more than his party could win . in
#
#  say there you ’ re an old place with raheel on pakistan .
#
#  the answer , though , is that they ’ re one who is to get it , only one side will eventually got
#
# big business .
#
#  at least that is the election doing .
#
#  the possibility of the 18th amendment is that the ppp was the latest guy under the 22nd amendment it would be to come . ) ”
#
#  - - and a ppp leader , was never really looked like that : no , no , our boys , don ’ t rule . not very much . either way , when we — and then past had another five years .
#
#  pti 2018 was another zia . cpec and the boys continue because there is also why they are ?
#
#  yes , india ? this army ’ s security ? it ’ s the only thing that could be success , if you had nawaz the pml - n would have done that much more on his mind — and the other weak , the weak - based and the army leadership has never seen it this way . but when we stop an election , ” sharif says .
#
#  “ the last two judges we ’ ll come with this , though , delicious days .
#
#  the economic interventions have been received : stop inflation and talking intelligence agencies , he ’ ll likely won ’ t be imran ’ s to let the world this country ? — everyone will have to put those in sindh . fight for a different category .
#
#  but all of that is meaningless if we just have a look at nawaz .
#
#  raheel and maryam go for much — even , so time can be done .
#
#  the end of the past had begun , the clinton has claimed that its border
#
# is , because of trying to understand each other and the boys wrong .
#
#  rewind to the end of last year and na ’ s have proved much as he is . imran ’ s instincts are dragging us last week .
#
#  maryam has also known that in many ways the army can only guess what it could be set in is already very different — in this business than they ’ re just as good to nawaz and imran , you always can ’ t share .
#
#  but if nawaz can ’ t wrest the fata .
#
#  but fear isn ’ t .
#
#  because what nawaz says and what if he ( says or this top job , his leadership to the boys — have roughly a nawaz and still that . but nawaz doesn ’ t have a choice ; it is with a strategy . ”
#
#  behind those claims and added into a different kind of society . in these games you could sense some of the uncertainty over what the will wants .
#
#  not our army if india gets there such a great deal with pakistani money is needed to itself up . so will he arrived at .
#
#  so , by the army can ’ t fight ; and the is at large .
#
#  but what the heck is what imran decided . )
#
#  ( where imran is us ? ) don ’ t get rid of the taliban .
#
#  so it ’ s an impasse — again . except now at an elevated level of conflict : afghanistan prods us , we prod afghanistan .
#
#  and we ’ ve been
#
# Epoch 21/25
# 485/485 [==============================] - 78s 161ms/step - loss: 0.4503
# Epoch 22/25
# 485/485 [==============================] - 77s 158ms/step - loss: 0.3945
# Epoch 23/25
# 485/485 [==============================] - 78s 161ms/step - loss: 0.3455
# Epoch 24/25
# 485/485 [==============================] - 77s 159ms/step - loss: 0.3065
# Epoch 25/25
# 485/485 [==============================] - 77s 159ms/step - loss: 0.2757
# ####################
# Temperature: 0.2
# ####################
# , blame events in the pml - n itself as a party of pti in punjab .
#
#  with the pml - n , it ’ s not like nawaz has a huge legislative agenda anyway . and even in this most bitterly divided current parliament when push has come to shove , legislation has moved through a minority - government senate .
#
#  for the ppp , the ppp , the pml - q , the religious parties , wherever there is an opening . a pti - pml - n deal wouldn ’ t automatically eliminate serious electoral competition at the constituency level .
#
#  second , constituency victories are a combination of what ’ s referred to as the electoral wind or wave — which is shaped nationally — and the local dharra .
#
#  link up with the pml - n , however covertly , and it ’ ll take the wind out of the pti sail , whose appeal is based on a rejection of the status - quo powers .
#
#  the n - league will secretly be pleased the census is being disputed because it defers addressing the matter of readjusting provincial seat shares ( already complicated by the possibility of a constitutional amendment being needed ) .
#
#  so , a two - way fight in punjab with the winner taking all , just like in 2013 — sounds simple enough , right ?
#
#  possibly . until you remember that 2013 had threatened to look like 2008 until the results poured in .
#
#  back then , back in 2008 , a ppp sympathy wave had failed to materialise , pml - n surged to unexpected gains and the pml - q crumbled
#
# full - and - apology - ; call - it - ended .
#
#  + - +
#
#  the next five years
#
#  + - +
#
#  the next five years
#
#  + - +
#
#  the end of dissent
#
#  as with saleem shahzad , the honest and the unflinching can predict how this will eventually be spun : a necessary aberration ; an exception , not the rule ; private business .
#
#  but this isn ’ t the old party , that ’ s the pml - n ’ s fiercest in the run - up to last may ’ s election that the media was for the pti ? is a member of the jui - f , as were the last two mnas from the agency : malik wazir ( na - 41 in 2008 ) and maulana merajuddin ( na - 42 in 2002 ) .
#
#  now , however , a pti candidate , dost mohammad khan , looks set to give the jui - f a tough fight in na - 42 , the mehsud - dominated constituency in which no election has been held since 2002 .
#
#  khan , a recently retired bureaucrat who is close to the pti chief imran khan , explained why he believes he can successfully take on the jui - f : “ maulana through the mosques and madressahs in the area , that ’ s how he cultivated his support .
#
#  the national security threat is what insurgents and outsiders thought and that money and soon .
#
#  the boys love their games . they are what they are ?
#
#  and against the whether the ttp is aware of
#
# course , the of the boys have to be embraced — and the state that is doing a violent part .
#
#  let ’ s turn . balochistan — and in a way things would eventually be made . and the chief is a good guy .
#
#  and you can sense the pml - n ’ s strategy — already , economic , the judiciary couldn ’ t do it under the constitution and keep the money and say , try to go up in the middle of ’ s anti - politics . more obvious than about the pml - n too :
#
#  the pml - n is a bunch of barons , out to sell the national silver . the ppp are a bunch of who think the federal kitty is their personal distribution fund . and the pti are a bunch of awkward opportunists , torn between corporate sense and political opportunity .
#
#  it ’ s a good story . the americans seem to politely agree . the chinese are sympathetic too . possibly because we ’ ve all seen it all a or two - star - for - the - means - again option .
#
#  “ i knew that the issue has given us the law to keep the whole out of and talks .
#
#  the other possibility is a bit of sharif ’ s business , is the anti - corruption , the state must down , like a third - term prime minister was the last prime minister being in a mystery for didn ’ t been there yet .
#
#  take this business of it . they ’ d have just fine , they won ’ t go for the
#
# ####################
# Temperature: 0.5
# ####################
# full - and - apology - ; call - it - ended that works because the government can be given a new chief .
#
#  which is the point . gridlock , a country and a few problem needs to be made .
#
#  the pml - n had been expected to finish first and the pti to give it a run for its money — the only question was how close would they get .
#
#  but it ’ s a new world out there .
#
#  you can do the same thing .
#
#  + - +
#
#  on a mobile phone ? get the dawn mobile app : apple store | google play
#
#  sharif and the saudis
#
#  everyone knows the know how it is . if you check in the constitution , he ’ s being doing the job to have to make the world angry , is not a bad thing .
#
#  there was a deep bench of aziz and of the way to his people and , and to them , given the stories of their , on - the - - limits on - - shakargarh was a part of gurdaspur district in india before partition – the battle for na - 116 is shaping up to be a fierce , old - fashioned wrestling match .
#
#  in one corner is tariq anees , the schoolteacher ’ s son who has risen to affluence via a politics centred on a deft touch with the public and a formidable capacity for arm - twisting . in the other corner is danyal aziz , son of a legendary practitioner of rural politics and the once - dominant political force in shakargarh ,
#
# course , the provincial politician and the sindh are a lot of , but the public doesn ’ t really seem to know what local governments will do .
#
#  put some life and it could just be true ; pakistan has let the americans while it on the security side too .
#
#  the army high command says , we can ’ t go for the kill unless the politicians back us and the public supports us .
#
#  assume — and this is a fairly big assumption — that the army means it .
#
#  the other bit , imran , nawaz sharif , who is still stuck with the state ’ s control of the dollar .
#
#  to the pml - n from coming next year .
#
#  and that ’ s where the trouble began — something like a a new era . then what end ? to the two men who matter , so why the hell would you if they do a different problem : what ’ s the price we could do do is ever going to be put - up : an anti - india , anti - pakistan militancy addressed he has used to be a year of the electoral time . but when the pml - n did it ? the best - case scenario is that the n - league ’ s finance team actually believes the amnesty could net a great deal of money . that is a bit of the system .
#
#  he had , though , benefited from the obvious : if he is to say no 1 . he ’ s got quite a , not long - time government win . the pml - n
#
# new ppp in the pti ’ s politics , the n - league can be on the threat that he ’ s not willing and do what he really does ?
#
#  because they ’ re a different category , because they don ’ t belong in the militancy column , there ’ s no point trying to issues or confuse them . flat - out denial , then , is one possibility .
#
#  the fear of the 18th amendment has not been to the sindh - two problems . pti , though , in all of its seats , nawaz , back : one , a no closer to some kind of stability in afghanistan would a possibility — the more vulnerable may be .
#
#  in now , it ’ s possible to get a whole lot uglier . and that we ’ ve been here before the news week .
#
#  nawaz didn ’ t want to go away .
#
#  + - +
#
#  on a mobile phone ? get the dawn mobile app : apple store | google play
#
#  the old dream
#
#  mullah omar is dead . osama is gone . it has the end - of - an - era ring to it . which means , soon enough we ’ ll figure . say they a judge had worked the ground ’ right on and to their next felt .
#
#  but the n - league has several cards of its own to play .
#
#  first , it has disrupted the pti ’ s run - up to nov 2 . scattering protesters , detaining leaders — it will have an effect on potential crowd size next wednesday .
#
# ####################
# Temperature: 1.0
# ####################
# the heart of zia ’ s political because the taliban leadership has a way of .
#
#  y ’ know , like your freaked - out minders desperately spun afterwards and got you to say later . others ’ ll lose ? they haven ’ t . on none of the electoral stuff , there may be no real crisis , but the way for how .
#
#  the jit may have inadvertently reminded us why .
#
#  dar was the key to islamabad . if he doesn ’ t deliver , no , he can ’ t be sure his way out in november 2007 . he ’ s wanted to win but he only wants to believe that nawaz and his family have are their attention on the national stage . a is what the anti - taliban will is up to who or they will be .
#
#  the end goal : july trump presidential election , remember the day — “ he would make for a chief you take a life if you ’ ve heard the route ’ s response to the tv private sector over the previous five years .
#
#  it was in trouble for scandal , a chief ready to tell . democracy ’ s got is the same again : the court who wants direct access to the security apparatus ? not the serious and regional threat .
#
#  a clever tale , but as we got . if nawaz thinks , you ’ re probably right , with a sense of what the boys could be playing them again .
#
#  but this time in now , a year it would have been to real political greatest supreme court . but the implications
#
# to state means india that india has always insisted on its own who is corrupt and beholden to the people and that without require public - sector as as an opportunity to as much as imran .
#
#  but balochistan is not a problem . cpec is more than anything but somehow everyone was willing to say what ’ s really going on . sharif is in an even where no one would be .
#
#  in any case , he ’ s become clear that he will focus on nawaz him again : what is he about nawaz to keep the general around , boys , , how they always call them . “ it can be said , ”
#
#  peshawar came with an reality of how this afghan state was and give only a deal more than ever . ”
#
#  “ there is a question about to figure out what to do about this . the pti mpas weren ’ t electing themselves to the senate . or would win votes and , the government was to make elections happen .
#
#  the pml - n has figured out that democratic continuity is key . may as well cut it , let him have the advantage they can get over ?
#
#  three weeks since the late 1970s , 2013 was going to be by the supreme . musharraf is another one , the pti can be expected to send their position as a job .
#
#  but for all the favourable political winds , the n - league is strangely engulfed in zardari .
#
#  it was a wasted moment .
#
#  but the need are these army . small bore it is an and a
#
# course , india was about the best , state may have by the world of attack , security and taliban one , so , go back to the taliban .
#
#  we ’ ll have to find it worst by a mud when no one had a ppp ticket in na - campaign campaign in 2008 , ppp , which the government in the are line of their political enemies . the four - year - and - the - - the - army team could make an even more pressure imran for the may - to - be - updated crossed , we ’ ll turn out to india because we ’ ve never had the time of democracy . the boys are most about the game we ’ .
#
#  the last time , a khosa - led bench convicted gilani for contempt but left open the question of disqualification . three justices summarily dispatched the pm when they had had enough and the circus threatened to fight — or won ’ t just now ?
#
#  the civilians aren ’ t suddenly up to route and things were to get better after qadri ( first will have now ? ”
#
#  with coalition maths on issues , saudi , punjab , government and the boys ’ in afghanistan and we are more likely to talk about . pakistani security establishment ’ s afghan taliban in pakistan , a few here where everyone in the boys got their way , but it will let him come out for on the rest .
#
#  modi agrees that he was in the us that will either talk about reforms and democracy .
#
#  it ’ s not like anything else out of the police

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [1.0, 0.5, 0.2, 0.2]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download('{}_weights.hdf5'.format(model_name))
files.download('{}_vocab.json'.format(model_name))
files.download('{}_config.json'.format(model_name))

# %% [markdown]
# To recreate the model on your own computer, after installing textgenrnn and TensorFlow, you can create a Python script with:
#
# ```
# from textgenrnn import textgenrnn
# textgen = textgenrnn(weights_path='colaboratory_weights.hdf5',
#                        vocab_path='colaboratory_vocab.json',
#                        config_path='colaboratory_config.json')
#
# textgen.generate_samples(max_gen_length=1000)
# textgen.generate_to_file('textgenrnn_texts.txt', max_gen_length=1000)
# ```
#
# Have fun with your new model! :)

# %% [markdown]
# # Etcetera
#
# If the model fails to load on a local machine due to a model-size-not-matching bug (common in >30MB weights), this is due to a file export bug from Colaboratory. To work around this issue, save the weights to Google Drive with the two cells below and download from there.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': '{}_weights.hdf5'.format(model_name)})
uploaded.SetContentFile('{}_weights.hdf5'.format(model_name))
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1b6T6M32YnXs-c0NB-PEi6MhAdCuG7RHy

# %% [markdown]
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
